# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime


with open('./log_kafka.csv','r') as f:
    line = f.readline()
    timestamp = []
    cpu = []
    mem = []
    
    while line:
        words = line.split(",")
        timestamp.append(datetime.strptime(words[0],'%H:%M:%S.%f').time())
        cpu.append(float(words[1]))
        mem.append(float(words[2]))
        line = f.readline()
    kafkaDF = pd.DataFrame({'time':timestamp,'cpu':cpu, 'mem':mem})
kafkaDF.plot()

# %%
with open('./log_master.csv','r') as f:
    line = f.readline()
    timestamp = []
    cpu = []
    mem = []
    
    while line:
        words = line.split(",")
        timestamp.append(datetime.strptime(words[0],'%H:%M:%S.%f').time())
        cpu.append(float(words[1]))
        mem.append(float(words[2]))
        line = f.readline()
    masterDF = pd.DataFrame({'time':timestamp,'cpu':cpu, 'mem':mem})
masterDF.plot()

# %%
with open('./log_slave1.csv','r') as f:
    line = f.readline()
    timestamp = []
    cpu = []
    mem = []
    
    while line:
        words = line.split(",")
        timestamp.append(datetime.strptime(words[0],'%H:%M:%S.%f').time())
        cpu.append(float(words[1]))
        mem.append(float(words[2]))
        line = f.readline()
    slavesDF = pd.DataFrame({'time':timestamp,'cpu':cpu, 'mem':mem})
slavesDF.plot()

# %%
with open('./log_slave2.csv','r') as f:
    line = f.readline()
    timestamp = []
    cpu = []
    mem = []
    
    while line:
        words = line.split(",")
        timestamp.append(datetime.strptime(words[0],'%H:%M:%S.%f').time())
        cpu.append(float(words[1]))
        mem.append(float(words[2]))
        line = f.readline()
    slavesDF = pd.DataFrame({'time':timestamp,'cpu':cpu, 'mem':mem})
slavesDF.plot()

# %%
with open('./log_slave3.csv','r') as f:
    line = f.readline()
    timestamp = []
    cpu = []
    mem = []
    
    while line:
        words = line.split(",")
        timestamp.append(datetime.strptime(words[0],'%H:%M:%S.%f').time())
        cpu.append(float(words[1]))
        mem.append(float(words[2]))
        line = f.readline()
    slavesDF = pd.DataFrame({'time':timestamp,'cpu':cpu, 'mem':mem})
slavesDF.plot()

# %%
a = 2. # shape
n = 1.
s = np.random.weibull(a, 1000)
import matplotlib.pyplot as plt
x = np.arange(1,100.)/50.

def weib(x,n,a):
    return (a / n) * (x / n)**(a - 1) * np.exp(-(x / n)**a)

count, bins, ignored = plt.hist(np.random.weibull(a,1000))

scale = count.max()/weib(x, n, a).max()
plt.plot(x, weib(x, n, a)*scale)
plt.show()

# %%
print(scale)
# Out:
# 133.57668098982234
